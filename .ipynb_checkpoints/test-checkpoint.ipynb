# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/jinghuang/Desktop/MAS/high-priority-papers/result/consolidated/consolidated_features.csv')
df
# Out:
#         Unnamed: 0        date   permno ticker  ma_1_9  ma_2_9  ma_3_9  \
# 0                0  2000-01-31  87432.0      A       1       1       1
# 1                1  2000-02-29  87432.0      A       1       1       1
# 2                2  2000-03-31  87432.0      A       1       1       1
# 3                3  2000-04-28  87432.0      A       0       1       1
# 4                4  2000-05-31  87432.0      A       0       0       1
# ...            ...         ...      ...    ...     ...     ...     ...
# 150301      150301  2020-03-31  40539.0     ZY       0       0       0
# 150302      150302  2020-05-29  40539.0     ZY       0       0       0
# 150303      150303  2020-07-31  40539.0     ZY       0       0       0
# 150304      150304  2020-09-30  40539.0     ZY       1       1       1
# 150305      150305  2020-11-30  40539.0     ZY       1       1       1
#
#         ma_1_12  ma_2_12  ma_3_12  ...  te3_y  te5_y  te6_y  de1_y  de2_y  \
# ...

# %%
import sys
import time
for i in range(10):
    print("\rConsolidated features completed {}/{}.".format(i, 833), end='')
    sys.stdout.flush()
time.sleep(5)
for j in range(20):
    print("\rConsolidated features completed {}/{}.".format(j, 833), end='')
    #sys.stdout.flush()
# Out:
# Consolidated features completed 9/833.

# %%
df[['permno', 'DATE']]
# Out:
#         permno        DATE
# 0        87432  2000-01-31
# 1        87432  2000-02-29
# 2        87432  2000-03-31
# 3        87432  2000-04-28
# 4        87432  2000-05-31
# ...        ...         ...
# 180432   13788  2020-08-31
# 180433   13788  2020-09-30
# 180434   13788  2020-10-30
# 180435   13788  2020-11-30
# 180436   13788  2020-12-31
#
# [180437 rows x 2 columns]

# %%
df[df['ticker'] == 'AET']
# Out:
#       Unnamed: 0 ticker  permno        DATE       RET  SHROUT    absacc  \
# 5383        5395    AET   88845  2001-01-31 -0.068980  141484       NaN
# 5384        5396    AET   88845  2001-02-28 -0.026157  141484       NaN
# 5385        5397    AET   88845  2001-03-30 -0.035187  141484       NaN
# 5386        5398    AET   88845  2001-04-30 -0.215200  141484       NaN
# 5387        5399    AET   88845  2001-05-31 -0.171692  141484       NaN
# ...          ...    ...     ...         ...       ...     ...       ...
# 5593        5605    AET   88845  2018-07-31  0.029373  327100  0.038102
# 5594        5606    AET   88845  2018-08-31  0.063061  327100  0.038102
# 5595        5607    AET   88845  2018-09-28  0.012883  327100  0.038102
# 5596        5608    AET   88845  2018-10-31 -0.019473  327400  0.038102
# 5597        5609    AET   88845  2018-11-30  0.068669  327400  0.038102
#
#            acc    aeavol   age  ...  sin        sp  std_dolvol  std_turn  \
# ...

# %%
sp = pd.read_csv('/Users/jinghuang/Desktop/MAS/high-priority-papers/src/paper9/S&P500 companies list (2000 to 2020).csv')
sp
# Out:
#      Unnamed: 0 ticker   permno
# 0             0      A  87432.0
# 1             1     AA  24643.0
# 2             2    AAP  89217.0
# 3             3   AAPL  14593.0
# 4             4   ABBV  13721.0
# ..          ...    ...      ...
# 830         830    ZBH  89070.0
# 831         831   ZBRA  76795.0
# 832         832   ZION  84129.0
# 833         833    ZTS  13788.0
# 834         834     ZY  40539.0
#
# [835 rows x 3 columns]

# %%
df[df['ticker'] == sp['ticker'].unique()]
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [172], in <cell line: 1>()
# ----> 1 df[df['ticker'] == sp['ticker'].unique()]
#       2 df
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/ops/common.py:70, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      66             return NotImplemented
#      68 other = item_from_zerodim(other)
# ---> 70 return method(self, other)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/arraylike.py:40, in OpsMixin.__eq__(self, other)
#      38 @unpack_zerodim_and_defer("__eq__")
#      39 def __eq__(self, other):
# ---> 40     return self._cmp_method(other, operator.eq)
#
# ...

# %%
l = []
for ticker in df['ticker'].unique():
    l.append(ticker.lower())
l
# Out:
# ['a',
#  'aa',
#  'aal',
#  'aap',
#  'aapl',
#  'abbv',
#  'abc',
#  'abi',
#  'abk',
#  'abmd',
#  'abs',
#  'abt',
#  'acas',
#  'ack',
#  'acn',
#  'acs',
#  'acv',
#  'adbe',
#  'adct',
#  'adi',
#  'adm',
#  'adnt',
#  'adp',
#  'ads',
#  'adsk',
#  'adt',
#  'aee',
#  'aep',
#  'aes',
#  'aet',
#  'afl',
#  'afs',
#  'agc',
#  'agn',
#  'aig',
#  'aiv',
#  'aiz',
#  'ajg',
#  'akam',
#  'aks',
#  'al',
#  'alb',
#  'algn',
#  'alk',
#  'all',
#  'alle',
#  'altr',
#  'alxn',
#  'am',
#  'amat',
#  'amcc',
#  'amcr',
#  'amd',
#  'ame',
#  'amg',
#  'amgn',
#  'amp',
#  'amt',
#  'amzn',
#  'an',
#  'andv',
#  'andw',
#  'anet',
#  'anf',
#  'anr',
#  'anss',
#  'antm',
#  'aon',
#  'aos',
#  'apa',
#  'apc',
#  'apcc',
#  'apd',
#  'aph',
#  'apol',
#  'aptv',
#  'arc',
#  'are',
#  'arg',
#  'ash',
#  'asix',
#  'asn',
#  'aso',
#  'at',
#  'atge',
#  'ati',
#  'ato',
#  'atvi',
#  'av',
#  'avb',
#  'avgo',
#  'avp',
#  'avy',
#  'aw',
#  'awe',
#  'awk',
#  'axp',
# ...

# %%
sp['ticker'].unique()
# Out:
# array(['A', 'AA', 'AAP', 'AAPL', 'ABBV', 'ABD', 'ABS', 'ABT', 'ABUD',
#        'ABXFF', 'ACAS', 'ACCOB', 'ACK', 'ACN', 'ACSA', 'ADCO', 'ADM',
#        'ADNT', 'ADS', 'ADSK', 'AEP', 'AESC', 'AET', 'AEXP', 'AFI', 'AFL',
#        'AFNL', 'AFS', 'AGAS', 'AGC', 'AGO', 'AGREA', 'AIGR', 'AIZ', 'AJG',
#        'AKAM', 'AKS', 'ALGN', 'ALK', 'ALLE', 'ALTR', 'ALXN', 'AMAT',
#        'AMB', 'AMCR', 'AMDV', 'AME', 'AMG', 'AMGN', 'AMR', 'AMSGA',
#        'AMZN', 'AN', 'ANDW', 'ANLG', 'ANR', 'ANSS', 'ANTM', 'AON', 'APA',
#        'APCC', 'APD', 'APOLA', 'ARG', 'ASD', 'ASH', 'ASHC', 'ASN', 'ASQ',
#        'ATG', 'ATI', 'ATVI', 'AV', 'AVGO', 'AVP', 'AVY', 'AWIN', 'AYI',
#        'AYP', 'AZA', 'AZO', 'AZP', 'BA', 'BAC', 'BARL', 'BAX', 'BBBY',
#        'BBT', 'BBWI', 'BBY', 'BC', 'BCMP', 'BCR', 'BDK', 'BDX', 'BFO',
#        'BGE', 'BGENF', 'BGG', 'BGH', 'BHF', 'BHI', 'BIIB', 'BIO', 'BIVV',
#        'BJS', 'BK', 'BKLY', 'BLK', 'BLKR', 'BLL', 'BLS', 'BMCS', 'BMET',
# ...

# %%
df['ticker'].unique()
# Out:
# array(['A', 'AA', 'AAL', 'AAP', 'AAPL', 'ABBV', 'ABC', 'ABI', 'ABK',
#        'ABMD', 'ABS', 'ABT', 'ACAS', 'ACK', 'ACN', 'ACS', 'ACV', 'ADBE',
#        'ADCT', 'ADI', 'ADM', 'ADNT', 'ADP', 'ADS', 'ADSK', 'ADT', 'AEE',
#        'AEP', 'AES', 'AET', 'AFL', 'AFS', 'AGC', 'AGN', 'AIG', 'AIV',
#        'AIZ', 'AJG', 'AKAM', 'AKS', 'AL', 'ALB', 'ALGN', 'ALK', 'ALL',
#        'ALLE', 'ALTR', 'ALXN', 'AM', 'AMAT', 'AMCC', 'AMCR', 'AMD', 'AME',
#        'AMG', 'AMGN', 'AMP', 'AMT', 'AMZN', 'AN', 'ANDV', 'ANDW', 'ANET',
#        'ANF', 'ANR', 'ANSS', 'ANTM', 'AON', 'AOS', 'APA', 'APC', 'APCC',
#        'APD', 'APH', 'APOL', 'APTV', 'ARC', 'ARE', 'ARG', 'ASH', 'ASIX',
#        'ASN', 'ASO', 'AT', 'ATGE', 'ATI', 'ATO', 'ATVI', 'AV', 'AVB',
#        'AVGO', 'AVP', 'AVY', 'AW', 'AWE', 'AWK', 'AXP', 'AYE', 'AYI',
#        'AZA', 'AZO', 'BA', 'BAC', 'BAX', 'BBBY', 'BBY', 'BC', 'BCR',
#        'BDK', 'BDX', 'BEAM', 'BEN', 'BF', 'BFO', 'BGEN', 'BGG', 'BHF',
# ...

# %%
# paper1.csv
df[df['ticker'] == 'ATG']
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, ticker, permno, DATE, RET, SHROUT, absacc, acc, aeavol, age, agr, baspread, beta, betasq, bm, bm_ia, cash, cashdebt, cashpr, cfp, cfp_ia, chatoia, chcsho, chempia, chinv, chmom, chpmia, chtx, cinvest, convind, currat, depr, divi, divo, dolvol, dy, ear, egr, ep, gma, grcapx, grltnoa, herf, hire, idiovol, ill, indmom, invest, lev, lgr, maxret, mom12m, mom1m, mom36m, mom6m, ms, mve0, mve_ia, mvel1, nincr, operprof, orgcap, pchcapx_ia, pchcurrat, pchdepr, pchgm_pchsale, pchquick, pchsale_pchinvt, pchsale_pchrect, pchsale_pchxsga, pchsaleinv, pctacc, prc, pricedelay, ps, quick, rd, rd_mve, rd_sale, realestate, retvol, roaq, roavol, roeq, roic, rsup, salecash, saleinv, salerec, secured, securedind, sgr, sic2, sin, sp, std_dolvol, std_turn, stdacc, stdcf, tang, ...]
# Index: []
#
# [0 rows x 103 columns]

# %%
len(df['ticker'].unique())
# Out:
# 988

# %%
len(sp['ticker'].unique())
# Out:
# 835

# %%
#sp['ticker'].unique()
count = 0
for ticker in sp['ticker'].unique():
    if ticker not in df['ticker'].unique():
        print(ticker)
        count += 1
print(count)
# Out:
# ABD
# ABUD
# ABXFF
# ACCOB
# ACSA
# ADCO
# AESC
# AEXP
# AFI
# AFNL
# AGAS
# AGO
# AGREA
# AIGR
# AMB
# AMDV
# AMR
# AMSGA
# ANLG
# APOLA
# ASD
# ASHC
# ASQ
# ATG
# AWIN
# AYP
# AZP
# BARL
# BBT
# BBWI
# BCMP
# BGE
# BGENF
# BGH
# BHI
# BKLY
# BLKR
# BMCS
# BPR
# BYA
# CCII
# CDA
# CDIC
# CDNC
# CEFT
# CLCH
# CMZ
# CNAG
# CNTE
# COFI
# COH
# CRCH
# CSC
# CUCD
# CUM
# CVTY
# CWE
# CZT
# DBKT
# DLPH
# DNY
# DOLR
# DRHI
# DV
# DWDP
# EGRP
# EMCS
# EPG
# FCMB
# FDP
# FEMP
# FNAC
# FNG
# FON
# FRRI
# FTEN
# FUNC
# FWC
# GART
# GBLX
# GCI
# GXP
# HCFDS
# HMAIA
# HMT
# HOC
# HOU
# HR
# HRS
# IACI
# IGL
# IILG
# IIN
# INI
# INX
# IVGN
# JEC
# KMRT
# KNB
# LIZ
# LKQX
# LLSI
# LOM
# LOWE
# LTR
# LUK
# MCCRK
# MCRN
# MDTR
# MFS
# MGG
# MGNE
# MID
# MILI
# MNBT
# MOHK
# MOT
# MPTR
# MRIS
# MRKT
# MWD
# MWV
# MXB
# NCO
# NDCO
# NHLI
# NIKE
# NLV
# NME
# NU
# OCF
# ODEP
# OEC
# OKEN
# P
# PCCW
# PCLN
# PCST
# PE
# PEB
# PFI
# PLMO
# PSVB
# PTRAS
# QWST
# RDR
# RESM
# RFMD
# RHAT
# ROPR
# SAFC
# ...

# %%
# ticker subset
# add permno back
# merge
len(df['ticker'].unique())
# Out:
# 988

# %%
df[df['ticker'] == 'ATG']
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, ticker, permno, DATE, RET, SHROUT, absacc, acc, aeavol, age, agr, baspread, beta, betasq, bm, bm_ia, cash, cashdebt, cashpr, cfp, cfp_ia, chatoia, chcsho, chempia, chinv, chmom, chpmia, chtx, cinvest, convind, currat, depr, divi, divo, dolvol, dy, ear, egr, ep, gma, grcapx, grltnoa, herf, hire, idiovol, ill, indmom, invest, lev, lgr, maxret, mom12m, mom1m, mom36m, mom6m, ms, mve0, mve_ia, mvel1, nincr, operprof, orgcap, pchcapx_ia, pchcurrat, pchdepr, pchgm_pchsale, pchquick, pchsale_pchinvt, pchsale_pchrect, pchsale_pchxsga, pchsaleinv, pctacc, prc, pricedelay, ps, quick, rd, rd_mve, rd_sale, realestate, retvol, roaq, roavol, roeq, roic, rsup, salecash, saleinv, salerec, secured, securedind, sgr, sic2, sin, sp, std_dolvol, std_turn, stdacc, stdcf, tang, ...]
# Index: []
#
# [0 rows x 103 columns]

# %%
len(df['ticker'].unique())
# Out:
# 988

# %%
df[df['ticker'] == 'AET']
# Out:
#       Unnamed: 0 ticker  permno        DATE       RET  SHROUT    absacc  \
# 5383        5395    AET   88845  2001-01-31 -0.068980  141484       NaN
# 5384        5396    AET   88845  2001-02-28 -0.026157  141484       NaN
# 5385        5397    AET   88845  2001-03-30 -0.035187  141484       NaN
# 5386        5398    AET   88845  2001-04-30 -0.215200  141484       NaN
# 5387        5399    AET   88845  2001-05-31 -0.171692  141484       NaN
# ...          ...    ...     ...         ...       ...     ...       ...
# 5593        5605    AET   88845  2018-07-31  0.029373  327100  0.038102
# 5594        5606    AET   88845  2018-08-31  0.063061  327100  0.038102
# 5595        5607    AET   88845  2018-09-28  0.012883  327100  0.038102
# 5596        5608    AET   88845  2018-10-31 -0.019473  327400  0.038102
# 5597        5609    AET   88845  2018-11-30  0.068669  327400  0.038102
#
#            acc    aeavol   age  ...  sin        sp  std_dolvol  std_turn  \
# ...

# %%
df['permno'].unique()
# Out:
# array([87432, 16347, 21020, 89217, 14593, 13721, 81540, 27713, 76757,
#        75107, 50032, 20482, 85271, 19692, 89071, 80913, 42083, 75510,
#        50906, 60871, 10516, 16342, 44644, 89002, 85631, 13567, 24985,
#        24109, 76712, 88845, 57904, 83440, 48397, 75646, 66800, 80711,
#        90038, 38093, 87299, 80303, 24264, 80191, 88860, 28804, 79323,
#        14297, 75577, 83111, 13056, 14702, 85522, 18724, 61241, 85257,
#        85593, 14008, 90880, 86111, 84788, 76282, 37284, 14323, 14714,
#        83976, 90547, 83621, 89179, 61735, 65402, 39490, 70332, 11970,
#        28222, 84769, 81138, 13103, 10604, 84767, 70308, 24272, 16276,
#        64451, 62770, 41443, 76708, 43123, 32986, 79678, 88587, 80381,
#        93002, 40416, 44601, 76887, 89001, 92614, 59176, 10137, 89216,
#        64856, 76605, 19561, 59408, 27887, 77659, 85914, 10874, 46877,
#        20220, 39642, 10225, 37584, 29946, 10989, 11983, 17961, 16816,
# ...

# %%
df[df['permno'] == 46850]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, ticker, permno, DATE, RET, SHROUT, absacc, acc, aeavol, age, agr, baspread, beta, betasq, bm, bm_ia, cash, cashdebt, cashpr, cfp, cfp_ia, chatoia, chcsho, chempia, chinv, chmom, chpmia, chtx, cinvest, convind, currat, depr, divi, divo, dolvol, dy, ear, egr, ep, gma, grcapx, grltnoa, herf, hire, idiovol, ill, indmom, invest, lev, lgr, maxret, mom12m, mom1m, mom36m, mom6m, ms, mve0, mve_ia, mvel1, nincr, operprof, orgcap, pchcapx_ia, pchcurrat, pchdepr, pchgm_pchsale, pchquick, pchsale_pchinvt, pchsale_pchrect, pchsale_pchxsga, pchsaleinv, pctacc, prc, pricedelay, ps, quick, rd, rd_mve, rd_sale, realestate, retvol, roaq, roavol, roeq, roic, rsup, salecash, saleinv, salerec, secured, securedind, sgr, sic2, sin, sp, std_dolvol, std_turn, stdacc, stdcf, tang, ...]
# Index: []
#
# [0 rows x 103 columns]

# %%
df = pd.read_csv('/Users/jinghuang/Desktop/MAS/high-priority-papers/result/paper8/paper8_features.csv')
df
# Out:
#         Unnamed: 0 ticker  permno        DATE       RET  SHROUT    absacc  \
# 0                0      A   87432  2000-01-31 -0.143897  452000       NaN
# 1                1      A   87432  2000-02-29  0.569405  452000       NaN
# 2                2      A   87432  2000-03-31  0.001203  452000       NaN
# 3                3      A   87432  2000-04-28 -0.147837  452000       NaN
# 4                4      A   87432  2000-05-31 -0.169252  452000       NaN
# ...            ...    ...     ...         ...       ...     ...       ...
# 180432      183366    ZTS   13788  2020-08-31  0.055512  475145  0.026431
# 180433      183367    ZTS   13788  2020-09-30  0.032917  475145  0.026431
# 180434      183368    ZTS   13788  2020-10-30 -0.040031  475145  0.026431
# 180435      183369    ZTS   13788  2020-11-30  0.011542  475268  0.026431
# 180436      183370    ZTS   13788  2020-12-31  0.031924  475268  0.026431
#
#              acc    aeavol  age  ...  sin       sp  std_dolvol  std_turn  \
# ...

# %%
df[df['ticker'] == 'AET']
# Out:
#       Unnamed: 0 ticker  permno        DATE       RET  SHROUT    absacc  \
# 5383        5395    AET   88845  2001-01-31 -0.068980  141484       NaN
# 5384        5396    AET   88845  2001-02-28 -0.026157  141484       NaN
# 5385        5397    AET   88845  2001-03-30 -0.035187  141484       NaN
# 5386        5398    AET   88845  2001-04-30 -0.215200  141484       NaN
# 5387        5399    AET   88845  2001-05-31 -0.171692  141484       NaN
# ...          ...    ...     ...         ...       ...     ...       ...
# 5593        5605    AET   88845  2018-07-31  0.029373  327100  0.038102
# 5594        5606    AET   88845  2018-08-31  0.063061  327100  0.038102
# 5595        5607    AET   88845  2018-09-28  0.012883  327100  0.038102
# 5596        5608    AET   88845  2018-10-31 -0.019473  327400  0.038102
# 5597        5609    AET   88845  2018-11-30  0.068669  327400  0.038102
#
#            acc    aeavol   age  ...  sin        sp  std_dolvol  std_turn  \
# ...

# %%
type(df['date'][0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
#df['date'] = pd.to_datetime(df['date'])
df.set_index('date', inplace=True)
#df.index = df.index.to_period('M')
#df['yyyy-mm']

# %%
df.index = df.index.to_period('M')

# %%
df.index
# Out:
# PeriodIndex(['2000-01', '2000-01', '2000-01', '2000-01', '2000-01', '2000-01',
#              '2000-01', '2000-01', '2000-01', '2000-01',
#              ...
#              '2020-01', '2020-01', '2020-01', '2020-01', '2020-01', '2020-01',
#              '2020-01', '2020-01', '2020-01', '2020-01'],
#             dtype='period[M]', name='date', length=252)

# %%
df = pd.read_csv('/Users/jinghuang/Desktop/MAS/high-priority-papers/src/paper3_features.csv')
df
# Out:
#         Unnamed: 0        date  permno ticker          a2me       ato  \
# 0                0  2000-01-31   10078   JAVA  1.091861e-03 -0.804783
# 1                1  2000-02-29   10078   JAVA  1.170049e-08 -0.804783
# 2                2  2000-03-31   10078   JAVA           NaN -0.804783
# 3                3  2000-04-28   10078   JAVA           NaN       NaN
# 4                4  2000-05-31   10078   JAVA           NaN       NaN
# ...            ...         ...     ...    ...           ...       ...
# 183216      183216  2020-08-31   93436   TSLA  1.286720e-04  1.632981
# 183217      183217  2020-09-30   93436   TSLA  7.388782e-05  1.632981
# 183218      183218  2020-10-30   93436   TSLA  8.435917e-05  1.632981
# 183219      183219  2020-11-30   93436   TSLA  9.327571e-05  1.632981
# 183220      183220  2020-12-31   93436   TSLA  9.692422e-05  1.632981
#
#                 beme         c       c2d       cto  ...    r_12_7     r_6_2  \
# ...

# %%
df[df['ticker'] == 'AET']
# Out:
#         Unnamed: 0        date  permno ticker      a2me        ato      beme  \
# 67612        67612  2000-01-31   46850    AET  0.001125   2.571306 -0.001723
# 67613        67613  2000-02-29   46850    AET  0.000018   2.571306 -0.000027
# 67614        67614  2000-03-31   46850    AET  0.000024   2.571306 -0.000037
# 67615        67615  2000-04-28   46850    AET  0.000018   2.571306 -0.000027
# 67616        67616  2000-05-31   46850    AET       NaN   2.571306 -0.000026
# ...            ...         ...     ...    ...       ...        ...       ...
# 163595      163595  2018-06-29   88845    AET  0.000957 -23.547721  0.000270
# 163596      163596  2018-07-31   88845    AET  0.000919 -23.547721  0.000260
# 163597      163597  2018-08-31   88845    AET  0.000895 -23.547721  0.000253
# 163598      163598  2018-09-28   88845    AET  0.000842 -23.547721  0.000238
# 163599      163599  2018-10-31   88845    AET  0.000831 -23.547721  0.000235
#
# ...

# %%
type(df['date'][0])
# Out:
# str

# %%
df = pd.read_csv('/Users/jinghuang/Desktop/MAS/high-priority-papers/result/paper4/paper4_features.csv')
df
# Out:
#         Unnamed: 0        date  permno ticker          size         value  \
# 0                0  2000-01-31   10078   JAVA  1.314270e+03 -1.775891e-03
# 1                1  2000-02-29   10078   JAVA  1.226444e+08 -1.903063e-08
# 2                2  2000-03-31   10078   JAVA  1.486953e+08 -1.569652e-08
# 3                3  2000-04-28   10078   JAVA  1.486519e+08           NaN
# 4                4  2000-05-31   10078   JAVA  1.460543e+08           NaN
# ...            ...         ...     ...    ...           ...           ...
# 183216      183216  2020-08-31   93436   TSLA  2.666393e+08  2.482005e-05
# 183217      183217  2020-09-30   93436   TSLA  4.643391e+08  1.425252e-05
# 183218      183218  2020-10-30   93436   TSLA  4.067015e+08  1.627238e-05
# 183219      183219  2020-11-30   93436   TSLA  3.678235e+08  1.799232e-05
# 183220      183220  2020-12-31   93436   TSLA  5.380286e+08  1.230046e-05
#
#             prof   valprof     nissa    growth  ...     lrrev        valuem  \
# ...

# %%
type(df['date'][0])
# Out:
# str

# %%
df = pd.read_csv('/Users/jinghuang/Desktop/MAS/high-priority-papers/src/paper8_features.csv')
df
# Out:
#         Unnamed: 0 ticker  permno        DATE       RET  SHROUT    absacc  \
# 0                0      A   87432  2000-01-31 -0.143897  452000       NaN
# 1                1      A   87432  2000-02-29  0.569405  452000       NaN
# 2                2      A   87432  2000-03-31  0.001203  452000       NaN
# 3                3      A   87432  2000-04-28 -0.147837  452000       NaN
# 4                4      A   87432  2000-05-31 -0.169252  452000       NaN
# ...            ...    ...     ...         ...       ...     ...       ...
# 180432      183366    ZTS   13788  2020-08-31  0.055512  475145  0.026431
# 180433      183367    ZTS   13788  2020-09-30  0.032917  475145  0.026431
# 180434      183368    ZTS   13788  2020-10-30 -0.040031  475145  0.026431
# 180435      183369    ZTS   13788  2020-11-30  0.011542  475268  0.026431
# 180436      183370    ZTS   13788  2020-12-31  0.031924  475268  0.026431
#
#              acc    aeavol  age  ...  sin       sp  std_dolvol  std_turn  \
# ...

# %%
df[df['ticker'] == 'AET']
# Out:
#       Unnamed: 0 ticker  permno        DATE       RET  SHROUT    absacc  \
# 5383        5395    AET   88845  2001-01-31 -0.068980  141484       NaN
# 5384        5396    AET   88845  2001-02-28 -0.026157  141484       NaN
# 5385        5397    AET   88845  2001-03-30 -0.035187  141484       NaN
# 5386        5398    AET   88845  2001-04-30 -0.215200  141484       NaN
# 5387        5399    AET   88845  2001-05-31 -0.171692  141484       NaN
# ...          ...    ...     ...         ...       ...     ...       ...
# 5593        5605    AET   88845  2018-07-31  0.029373  327100  0.038102
# 5594        5606    AET   88845  2018-08-31  0.063061  327100  0.038102
# 5595        5607    AET   88845  2018-09-28  0.012883  327100  0.038102
# 5596        5608    AET   88845  2018-10-31 -0.019473  327400  0.038102
# 5597        5609    AET   88845  2018-11-30  0.068669  327400  0.038102
#
#            acc    aeavol   age  ...  sin        sp  std_dolvol  std_turn  \
# ...

# %%
df = pd.read_csv('/Users/jinghuang/Desktop/MAS/high-priority-papers/result/consolidated_papers/A.csv')
df
# Out:
#      Unnamed: 0     date  permno_x ticker_x  ma_1_9  ma_2_9  ma_3_9  ma_1_12  \
# 0             0  2000-01   87432.0        A       1       1       1        1
# 1             1  2000-02   87432.0        A       1       1       1        1
# 2             2  2000-03   87432.0        A       1       1       1        1
# 3             3  2000-04   87432.0        A       0       1       1        0
# 4             4  2000-05   87432.0        A       0       0       1        0
# ..          ...      ...       ...      ...     ...     ...     ...      ...
# 247         247  2020-08   87432.0        A       1       1       1        1
# 248         248  2020-09   87432.0        A       1       1       1        1
# 249         249  2020-10   87432.0        A       1       1       1        1
# 250         250  2020-11   87432.0        A       1       1       1        1
# 251         251  2020-12   87432.0        A       1       1       1        1
#
# ...

# %%
df = pd.read_csv('/Users/jinghuang/Desktop/MAS/high-priority-papers/result/paper3/paper3_features.csv')
df
# Out:
#         Unnamed: 0        date  permno ticker          a2me       ato  \
# 0                0  2000-01-31   10078   JAVA  1.091861e-03 -0.804783
# 1                1  2000-02-29   10078   JAVA  1.170049e-08 -0.804783
# 2                2  2000-03-31   10078   JAVA           NaN -0.804783
# 3                3  2000-04-28   10078   JAVA           NaN       NaN
# 4                4  2000-05-31   10078   JAVA           NaN       NaN
# ...            ...         ...     ...    ...           ...       ...
# 183216      183216  2020-08-31   93436   TSLA  1.286720e-04  1.632981
# 183217      183217  2020-09-30   93436   TSLA  7.388782e-05  1.632981
# 183218      183218  2020-10-30   93436   TSLA  8.435917e-05  1.632981
# 183219      183219  2020-11-30   93436   TSLA  9.327571e-05  1.632981
# 183220      183220  2020-12-31   93436   TSLA  9.692422e-05  1.632981
#
#                 beme         c       c2d       cto  ...    r_12_7     r_6_2  \
# ...

# %%
df = pd.read_csv('/Users/jinghuang/Desktop/MAS/high-priority-papers/result/paper2/paper2_features.csv')
df
# Out:
#           date  yyyy-mm  CRSP_SPvw  CRSP_SPvwx     Rfree       b/m     tbl  \
# 0     1/1/2000  2000-01  -0.049630   -0.050296  0.004333  0.154625  0.0532
# 1     1/2/2000  2000-02  -0.017458   -0.018666  0.004433  0.167025  0.0555
# 2     1/3/2000  2000-03   0.098488    0.097431  0.004625  0.149983  0.0569
# 3     1/4/2000  2000-04  -0.031583   -0.032308  0.004742  0.152610  0.0566
# 4     1/5/2000  2000-05  -0.022304   -0.023617  0.004717  0.155678  0.0579
# ..         ...      ...        ...         ...       ...       ...     ...
# 247   1/8/2020  2020-08   0.072068    0.070308  0.000108  0.235975  0.0010
# 248   1/9/2020  2020-09  -0.038151   -0.039366  0.000083  0.241482  0.0011
# 249  1/10/2020  2020-10  -0.026409   -0.027507  0.000092  0.253146  0.0010
# 250  1/11/2020  2020-11   0.109404    0.107624  0.000083  0.226352  0.0009
# 251  1/12/2020  2020-12   0.041572    0.040137  0.000075  0.219195  0.0009
#
# ...

# %%
df.set_index('yyyy-mm', inplace=True)

# %%
type(df.index[0])
# Out:
# str

# %%
df.index = pd.to_datetime(df.index)
df.index = df.index.to_period('M')
df.index
# Out:
# PeriodIndex(['2000-01', '2000-02', '2000-03', '2000-04', '2000-05', '2000-06',
#              '2000-07', '2000-08', '2000-09', '2000-10',
#              ...
#              '2020-03', '2020-04', '2020-05', '2020-06', '2020-07', '2020-08',
#              '2020-09', '2020-10', '2020-11', '2020-12'],
#             dtype='period[M]', name='yyyy-mm', length=252)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=252, step=1)

# %%
type(df['yyyy-mm'][0])
# Out:
# str

# %%
df = pd.read_csv('/Users/jinghuang/Desktop/MAS/high-priority-papers/result/consolidated_papers/A.csv')
df
# Out:
#      Unnamed: 0     date  permno_x ticker_x  ma_1_9  ma_2_9  ma_3_9  ma_1_12  \
# 0             0  2000-01   87432.0        A       1       1       1        1
# 1             1  2000-02   87432.0        A       1       1       1        1
# 2             2  2000-03   87432.0        A       1       1       1        1
# 3             3  2000-04   87432.0        A       0       1       1        0
# 4             4  2000-05   87432.0        A       0       0       1        0
# ..          ...      ...       ...      ...     ...     ...     ...      ...
# 247         247  2020-08   87432.0        A       1       1       1        1
# 248         248  2020-09   87432.0        A       1       1       1        1
# 249         249  2020-10   87432.0        A       1       1       1        1
# 250         250  2020-11   87432.0        A       1       1       1        1
# 251         251  2020-12   87432.0        A       1       1       1        1
#
# ...

# %%
daily_prc = pd.read_csv('/Users/jinghuang/Desktop/MAS/high-priority-papers/src/sp500_daily_prc.csv')
daily_prc['date'] = pd.to_datetime(daily_prc['date'])
daily_prc['year'] = daily_prc['date'].dt.year
daily_prc['month'] = daily_prc['date'].dt.month
daily_prc = daily_prc.sort_values(['ticker', 'date']).reset_index(drop=True)
lvlm_dt_ref = daily_prc.groupby(['year', 'month'])['date'].max()
lvlm_dt_ref #purpose is to find the last trading day of the month
date_dic = {}
df_date = lvlm_dt_ref.reset_index(level=['year','month'])
df_date.set_index('date',inplace=True)
df_date['YYMMDD']=df_date.index.astype(str)
df_date.index=df_date.index.to_period('M')
df_date.index=df_date.index.astype(str)

# %%
df_date
# Out:
#          year  month      YYMMDD
# date
# 1999-12  1999     12  1999-12-31
# 2000-01  2000      1  2000-01-31
# 2000-02  2000      2  2000-02-29
# 2000-03  2000      3  2000-03-31
# 2000-04  2000      4  2000-04-28
# ...       ...    ...         ...
# 2021-08  2021      8  2021-08-31
# 2021-09  2021      9  2021-09-30
# 2021-10  2021     10  2021-10-29
# 2021-11  2021     11  2021-11-30
# 2021-12  2021     12  2021-12-30
#
# [265 rows x 3 columns]

# %%
df_date['month'] = df_date['YYMMDD'].values

# %%
df_date
# Out:
#          year       month      YYMMDD     l
# date
# 1999-12  1999  1999-12-31  1999-12-31  1999
# 2000-01  2000  2000-01-31  2000-01-31  2000
# 2000-02  2000  2000-02-29  2000-02-29  2000
# 2000-03  2000  2000-03-31  2000-03-31  2000
# 2000-04  2000  2000-04-28  2000-04-28  2000
# ...       ...         ...         ...   ...
# 2021-08  2021  2021-08-31  2021-08-31  2021
# 2021-09  2021  2021-09-30  2021-09-30  2021
# 2021-10  2021  2021-10-29  2021-10-29  2021
# 2021-11  2021  2021-11-30  2021-11-30  2021
# 2021-12  2021  2021-12-30  2021-12-30  2021
#
# [265 rows x 4 columns]

# %%
a = pd.DataFrame()
type(a)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df_date['YYMMDD'][0])
# Out:
# str

# %%
type(df_date.index[0])
# Out:
# str

# %%
type(df_date.index[0])
# Out:
# str

# %%
df_date[df_date.index == '2000-01']['YYMMDD'][0]
# Out:
# '2000-01-31'

# %%
df_a = pd.read_csv('/Users/jinghuang/Desktop/MAS/high-priority-papers/result/paper9/A.csv', index_col=[0])
df_a
# Out:
#         date   permno       close      spyt     spyt1     spyt2     spyt3  \
# 0    2000-01  87432.0   66.187500       NaN       NaN       NaN       NaN
# 1    2000-02  87432.0  103.875000  0.569405       NaN       NaN       NaN
# 2    2000-03  87432.0  104.000000  0.001203  0.569405       NaN       NaN
# 3    2000-04  87432.0   88.625000 -0.147837  0.001203  0.569405       NaN
# 4    2000-05  87432.0   73.625000 -0.169252 -0.147837  0.001203  0.569405
# ..       ...      ...         ...       ...       ...       ...       ...
# 247  2020-08  87432.0  100.419998  0.042458  0.090076  0.002610  0.149752
# 248  2020-09  87432.0  100.940002  0.005178  0.042458  0.090076  0.002610
# 249  2020-10  87432.0  102.089996  0.011393  0.005178  0.042458  0.090076
# 250  2020-11  87432.0  116.900002  0.145068  0.011393  0.005178  0.042458
# 251  2020-12  87432.0  118.489998  0.013601  0.145068  0.011393  0.005178
#
#           rdp5      rdp10      rdp15  ...   de1   de2   de4   de5   de6   de7  \
# ...

# %%
type(df_a['date'][0])
# Out:
# str

# %%
df_a.loc[0,'date'] = '2000'
#df.loc[2, 'D1'] = 32

# %%
df_a
# Out:
#         date   permno       close      spyt     spyt1     spyt2     spyt3  \
# 0       2000  87432.0   66.187500       NaN       NaN       NaN       NaN
# 1    2000-02  87432.0  103.875000  0.569405       NaN       NaN       NaN
# 2    2000-03  87432.0  104.000000  0.001203  0.569405       NaN       NaN
# 3    2000-04  87432.0   88.625000 -0.147837  0.001203  0.569405       NaN
# 4    2000-05  87432.0   73.625000 -0.169252 -0.147837  0.001203  0.569405
# ..       ...      ...         ...       ...       ...       ...       ...
# 247  2020-08  87432.0  100.419998  0.042458  0.090076  0.002610  0.149752
# 248  2020-09  87432.0  100.940002  0.005178  0.042458  0.090076  0.002610
# 249  2020-10  87432.0  102.089996  0.011393  0.005178  0.042458  0.090076
# 250  2020-11  87432.0  116.900002  0.145068  0.011393  0.005178  0.042458
# 251  2020-12  87432.0  118.489998  0.013601  0.145068  0.011393  0.005178
#
#           rdp5      rdp10      rdp15  ...   de1   de2   de4   de5   de6   de7  \
# ...

# %%
for i in df_a.index:
    df_a['date'][i] = df_date[df_date.index == df_a['date'][i]]['YYMMDD'][0]
df_a
# Out:
# /var/folders/pf/6m70llld5kz3jp5trc8kh13w0000gn/T/ipykernel_6629/1806736320.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_a['date'][i] = df_date[df_date.index == df_a['date'][i]]['YYMMDD'][0]
#            date   permno       close      spyt     spyt1     spyt2     spyt3  \
# 0    2000-01-31  87432.0   66.187500       NaN       NaN       NaN       NaN
# 1    2000-02-29  87432.0  103.875000  0.569405       NaN       NaN       NaN
# 2    2000-03-31  87432.0  104.000000  0.001203  0.569405       NaN       NaN
# 3    2000-04-28  87432.0   88.625000 -0.147837  0.001203  0.569405       NaN
# 4    2000-05-31  87432.0   73.625000 -0.169252 -0.147837  0.001203  0.569405
# ..          ...      ...         ...       ...       ...       ...       ...
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=252, step=1)

# %%
df['date'] = df['date'].astype(str)
for i in df.index:
    #print(df['date'][i])
    #print(df_date[df_date.index == df['date'][i]])
    df['date'][i] = df_date[df_date.index == df['date'][i]]['YYMMDD'][0]
df
# Out:
# /var/folders/pf/6m70llld5kz3jp5trc8kh13w0000gn/T/ipykernel_6629/1719633213.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['date'][i] = df_date[df_date.index == df['date'][i]]['YYMMDD'][0]
#      Unnamed: 0        date  permno_x ticker_x  ma_1_9  ma_2_9  ma_3_9  \
# 0             0  2000-01-31   87432.0        A       1       1       1
# 1             1  2000-02-29   87432.0        A       1       1       1
# 2             2  2000-03-31   87432.0        A       1       1       1
# 3             3  2000-04-28   87432.0        A       0       1       1
# 4             4  2000-05-31   87432.0        A       0       0       1
# ..          ...         ...       ...      ...     ...     ...     ...
# 247         247  2020-08-31   87432.0        A       1       1       1
# ...

# %%
df_date.
# Out:
#          year  month      YYMMDD
# date
# 1999-12  1999     12  1999-12-31
# 2000-01  2000      1  2000-01-31
# 2000-02  2000      2  2000-02-29
# 2000-03  2000      3  2000-03-31
# 2000-04  2000      4  2000-04-28
# ...       ...    ...         ...
# 2021-08  2021      8  2021-08-31
# 2021-09  2021      9  2021-09-30
# 2021-10  2021     10  2021-10-29
# 2021-11  2021     11  2021-11-30
# 2021-12  2021     12  2021-12-30
#
# [265 rows x 3 columns]

# %%
import investpy
gold = investpy.get_currency_cross_historical_data(
            currency_cross='XAU/USD', from_date='01/01/2020', to_date='01/01/2021')
# Out:
# ---------------------------------------------------------------------------
# ConnectionError                           Traceback (most recent call last)
# Input In [103], in <cell line: 2>()
#       1 import investpy
# ----> 2 gold = investpy.get_currency_cross_historical_data(
#       3             currency_cross='XAU/USD', from_date='01/01/2020', to_date='01/01/2021')
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/investpy/currency_crosses.py:674, in get_currency_cross_historical_data(currency_cross, from_date, to_date, as_json, order, interval)
#     671 req = requests.post(url, headers=head, data=params)
#     673 if req.status_code != 200:
# --> 674     raise ConnectionError(
#     675         "ERR#0015: error " + str(req.status_code) + ", try again later."
#     676     )
#     678 if not req.text:
#     679     continue
#
# ConnectionError: ERR#0015: error 429, try again later.

# %%
import pandas as pd
pd.read_csv('/Users/jinghuang/Desktop/MAS/high-priority-papers/result/paper4/paper4_features.csv')
# Out:
#         Unnamed: 0        date  permno ticker          size         value  \
# 0                0  2000-01-31   10078   JAVA  1.314270e+03 -1.775891e-03
# 1                1  2000-02-29   10078   JAVA  1.226444e+08 -1.903063e-08
# 2                2  2000-03-31   10078   JAVA  1.486953e+08 -1.569652e-08
# 3                3  2000-04-28   10078   JAVA  1.486519e+08           NaN
# 4                4  2000-05-31   10078   JAVA  1.460543e+08           NaN
# ...            ...         ...     ...    ...           ...           ...
# 183216      183216  2020-08-31   93436   TSLA  2.666393e+08  2.482005e-05
# 183217      183217  2020-09-30   93436   TSLA  4.643391e+08  1.425252e-05
# 183218      183218  2020-10-30   93436   TSLA  4.067015e+08  1.627238e-05
# 183219      183219  2020-11-30   93436   TSLA  3.678235e+08  1.799232e-05
# 183220      183220  2020-12-31   93436   TSLA  5.380286e+08  1.230046e-05
#
#             prof   valprof     nissa    growth  ...     lrrev        valuem  \
# ...

# %%
import os
import re
import pandas as pd

# %%
daily_prc = pd.read_csv('/Users/jinghuang/Desktop/MAS/high-priority-papers/src/sp500_daily_prc.csv')
daily_prc['date'] = pd.to_datetime(daily_prc['date'])
daily_prc['year'] = daily_prc['date'].dt.year
daily_prc['month'] = daily_prc['date'].dt.month
daily_prc = daily_prc.sort_values(['ticker', 'date']).reset_index(drop=True)
lvlm_dt_ref = daily_prc.groupby(['year', 'month'])['date'].max()
lvlm_dt_ref #purpose is to find the last trading day of the month
date_dic = {}
df_date = lvlm_dt_ref.reset_index(level=['year','month'])
df_date.set_index('date',inplace=True)
df_date['YYMMDD']=df_date.index.astype(str)
df_date.index=df_date.index.to_period('M')
df_date.index=df_date.index.astype(str)

# %%
m = df_date.copy()

# %%
type(m.index[0])
# Out:
# str

# %%
df_date[df_date.index == '2000-01']['YYMMDD'][0]
# Out:
# '2000-01-31'

# %%
for i in os.listdir('/Users/jinghuang/Desktop/MAS/high-priority-papers/result/paper9'):
    if 'csv' not in i:
        print(i)
# Out:
# .DS_Store

# %%
for filename in os.listdir('/Users/jinghuang/Desktop/MAS/high-priority-papers/result/consolidated_papers'):
    df = pd.read_csv('/Users/jinghuang/Desktop/MAS/high-priority-papers/result/consolidated_papers/' \
                         + filename, index_col=[0])
    #f = pd.read_csv('/Users/jinghuang/Desktop/MAS/high-priority-papers/result/consolidated_papers/SITC.csv')
    print(filename)
    if 'date' not in df.columns:
        df.reset_index(inplace=True)
    if len(df['date'][0]) < 8:
        for i in df.index:
            df['date'][i] = df_date[df_date.index == df['date'][i]]['YYMMDD'][0]
    df.to_csv('/Users/jinghuang/Desktop/MAS/high-priority-papers/result/consolidated_papers/' \
                         + filename)
# Out:
# SITC.csv
# TROW.csv
# ISRG.csv
# PRGO.csv
# MOHK.csv
# ROPR.csv
# BUD.csv
# LUK.csv
# KRI.csv
# FON.csv
# NU.csv
# CR.csv
# AM.csv
# W.csv
# /var/folders/pf/6m70llld5kz3jp5trc8kh13w0000gn/T/ipykernel_6629/2467895327.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['date'][i] = df_date[df_date.index == df['date'][i]]['YYMMDD'][0]
# AGC.csv
# BCMP.csv
# /var/folders/pf/6m70llld5kz3jp5trc8kh13w0000gn/T/ipykernel_6629/2467895327.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['date'][i] = df_date[df_date.index == df['date'][i]]['YYMMDD'][0]
# ...

# %%
f = pd.read_csv('/Users/jinghuang/Desktop/MAS/high-priority-papers/result/consolidated_papers/SITC.csv', index_col=[0])
f.columns= f.columns.str.lower()
f
l = []
for col in f.columns:
    if '_x' in col:
        l.append(col)
 #       f = f.drop(columns=[col])
print(l)
#len(f.columns)
# Out:
# ['mom12_x', 'close_x', 'ema10_x', 'ema20_x', 'ema50_x', 'ema200_x', 'a2me_x', 'ato_x', 'beme_x', 'c_x', 'cto_x', 'pi2a_pctchange_x', 'e2p_x', 'investment_x', 'lev_x', 'lme_x', 'lturnover_x', 'noa_x', 'oa_x', 'ol_x', 'pcm_x', 'pm_x', 'prof_x', 'q_x', 'rna_x', 'roa_x', 'roe_x', 'r_12_2_x', 'r_12_7_x', 'r_2_1_x', 'r_36_13_x', 's2p_x', 'sga2s_x', 'sasdate_x', 'aaa_x', 'aaaffm_x', 'amdmnox_x', 'amdmuox_x', 'awhman_x', 'awotman_x', 'baa_x', 'baaffm_x', 'businvx_x', 'busloans_x', 'ce16ov_x', 'ces0600000007_x', 'ces0600000008_x', 'ces1021000001_x', 'ces2000000008_x', 'ces3000000008_x', 'claimsx_x', 'clf16ov_x', 'cmrmtsplx_x', 'compapffx_x', 'conspi_x', 'cp3mx_x', 'cpiappsl_x', 'cpiaucsl_x', 'cpimedsl_x', 'cpitrnsl_x', 'cpiulfsl_x', 'cumfns_x', 'cusr0000sa0l2_x', 'cusr0000sa0l5_x', 'cusr0000sac_x', 'cusr0000sad_x', 'cusr0000sas_x', 'ddurrg3m086sbea_x', 'dmanemp_x', 'dndgrg3m086sbea_x', 'dpcera3m086sbea_x', 'dserrg3m086sbea_x', 'dtcolnvhfnm_x', 'dtcthfnm_x', 'excausx_x', 'exjpusx_x', 'exszusx_
# ...

# %%
os.listdir('/Users/jinghuang/Desktop/MAS/high-priority-papers/result/consolidated_papers')[0]
# Out:
# 'SITC.csv'

# %%
'SITC.csv'.index('.')
# Out:
# 4

# %%
for filename in os.listdir('/Users/jinghuang/Desktop/MAS/high-priority-papers/result/consolidated_papers'):
    df = pd.read_csv('/Users/jinghuang/Desktop/MAS/high-priority-papers/result/consolidated_papers/' \
                         + filename, index_col=[0])
    df.columns= df.columns.str.lower()
    print(filename)
    for col in df.columns:
        if 'permno' in col and len(col) != len('permno'): permno_x 
            df = df.drop(columns=[col])
        if 'ticker' not in col:
            df['ticker'] = filename[:filename.index('.')]
        if 'ticker' in col and len(col) != len('ticker'):
            df = df.drop(columns=[col])
    df.insert(1, 'permno', df.pop('permno'))
    df.insert(2, 'ticker', df.pop('ticker'))
    df.to_csv('/Users/jinghuang/Desktop/MAS/high-priority-papers/result/consolidated_papers/' \
                         + filename)
# Out:
# SITC.csv
# TROW.csv
# ISRG.csv
# PRGO.csv
# MOHK.csv
# ROPR.csv
# BUD.csv
# LUK.csv
# KRI.csv
# FON.csv
# NU.csv
# CR.csv
# AM.csv
# W.csv
# AGC.csv
# BCMP.csv
# BA.csv
# GILD.csv
# ASQ.csv
# BXLT.csv
# SOTR.csv
# SLM.csv
# NLSN.csv
# THC.csv
# HWP.csv
# CNXT.csv
# EQIX.csv
# QLGC.csv
# TER.csv
# DCN.csv
# MID.csv
# TIF.csv
# MDT.csv
# ARC.csv
# CHX.csv
# CD.csv
# SZA.csv
# CIEN.csv
# A.csv
# CS.csv
# NC.csv
# WMIH.csv
# STJ.csv
# TRL.csv
# MO.csv
# SVU.csv
# SUN.csv
# SWKS.csv
# NCR.csv
# MCHP.csv
# FUNC.csv
# WLTW.csv
# MSCI.csv
# CHTR.csv
# EIX.csv
# RDR.csv
# OKEN.csv
# ERTS.csv
# BBY.csv
# ESV.csv
# SNDK.csv
# WBA.csv
# SPLS.csv
# FRRI.csv
# LVS.csv
# AJG.csv
# MZ.csv
# DTE.csv
# AFS.csv
# AN.csv
# C.csv
# AHAA.csv
# HOU.csv
# T.csv
# CF.csv
# DISH.csv
# INHL.csv
# TX.csv
# MER.csv
# ADNT.csv
# CDN.csv
# XL.csv
# SAI.csv
# TEG.csv
# WFMI.csv
# CLCH.csv
# TDC.csv
# MRKT.csv
# HUM.csv
# CBOE.csv
# PCST.csv
# ASD.csv
# TIE.csv
# SYY.csv
# HOT.csv
# CG.csv
# U.csv
# BC.csv
# ...

# %%
paper9_final = pd.DataFrame()
count = 0
for filename in os.listdir('/Users/jinghuang/Desktop/MAS/high-priority-papers/result/paper9'):
    if '.csv' in filename:
        df = pd.read_csv('/Users/jinghuang/Desktop/MAS/high-priority-papers/result/paper9/'+filename, index_col=[0])
        if count == 0:
            paper9_final = df
            count += 1
        else:
            paper9_final = pd.concat([paper9_final, df], ignore_index=True)
paper9_final
# Out:
#               date   permno ticker      close      spyt     spyt1     spyt2  \
# 0       2000-01-31  78927.0   SITC       13.0       NaN       NaN       NaN
# 1       2000-02-29  78927.0   SITC    11.5625 -0.110577       NaN       NaN
# 2       2000-03-31  78927.0   SITC     13.875       0.2 -0.110577       NaN
# 3       2000-04-28  78927.0   SITC    15.1875  0.094595       0.2 -0.110577
# 4       2000-05-31  78927.0   SITC    14.4375 -0.049383  0.094595       0.2
# ...            ...      ...    ...        ...       ...       ...       ...
# 155736  2008-05-30  15472.0    WWY  77.129997  0.012736  0.211967  0.049783
# 155737  2008-06-30  15472.0    WWY  77.779999  0.008427  0.012736  0.211967
# 155738  2008-07-31  15472.0    WWY  78.959999  0.015171  0.008427  0.012736
# 155739  2008-08-29  15472.0    WWY  79.480003  0.006586  0.015171  0.008427
# 155740  2008-09-30  15472.0    WWY  79.400002 -0.001007  0.006586  0.015171
#
# ...

# %%
len(paper9_final['ticker'].unique())
# Out:
# 833

# %%
paper9_final.to_csv('result/paper9_final/paper9_final.csv')

# %%
paper9 = pd.read_csv('/Users/jinghuang/Desktop/MAS/high-priority-papers/result/paper9_final/paper9_final.csv', index_col=[0])
paper9
# Out:
#               date   permno ticker      close      spyt     spyt1     spyt2  \
# 0       2000-01-31  78927.0   SITC  13.000000       NaN       NaN       NaN
# 1       2000-02-29  78927.0   SITC  11.562500 -0.110577       NaN       NaN
# 2       2000-03-31  78927.0   SITC  13.875000  0.200000 -0.110577       NaN
# 3       2000-04-28  78927.0   SITC  15.187500  0.094595  0.200000 -0.110577
# 4       2000-05-31  78927.0   SITC  14.437500 -0.049383  0.094595  0.200000
# ...            ...      ...    ...        ...       ...       ...       ...
# 155736  2008-05-30  15472.0    WWY  77.129997  0.012736  0.211967  0.049783
# 155737  2008-06-30  15472.0    WWY  77.779999  0.008427  0.012736  0.211967
# 155738  2008-07-31  15472.0    WWY  78.959999  0.015171  0.008427  0.012736
# 155739  2008-08-29  15472.0    WWY  79.480003  0.006586  0.015171  0.008427
# 155740  2008-09-30  15472.0    WWY  79.400002 -0.001007  0.006586  0.015171
#
# ...

# %%
paper9[paper9['ticker'] == 'O']
# Out:
#               date   permno ticker      close      spyt     spyt1     spyt2  \
# 139568  2000-01-31  81045.0      O  21.250000 -0.375918 -0.006709  0.016607
# 139569  2000-02-29  81045.0      O  20.812500 -0.560825  0.060416 -0.074550
# 139570  2000-03-31  81045.0      O  19.250000 -0.075075 -0.560825  0.060416
# 139571  2000-04-28  81045.0      O  21.812500 -0.558987  1.569351 -0.075075
# 139572  2000-05-31  81045.0      O  23.625000  0.083095 -0.558987  1.569351
# ...            ...      ...    ...        ...       ...       ...       ...
# 139815  2020-08-31  81045.0      O  62.029999  0.032973  0.009244  0.075755
# 139816  2020-09-30  81045.0      O  60.750000 -0.020635  0.032973  0.009244
# 139817  2020-10-30  81045.0      O  57.860001 -0.047572 -0.020635  0.032973
# 139818  2020-11-30  81045.0      O  59.970001  0.036467 -0.047572 -0.020635
# 139819  2020-12-31  81045.0      O  62.169998  0.036685  0.036467 -0.047572
#
# ...

# %%
paper11_final = pd.DataFrame()
count = 0
for filename in os.listdir('/Users/jinghuang/Desktop/MAS/high-priority-papers/result/paper11'):
    if '.csv' in filename:
        df = pd.read_csv('/Users/jinghuang/Desktop/MAS/high-priority-papers/result/paper11/'+filename, index_col=[0])
        if count == 0:
            paper11_final = df
            count += 1
        else:
            paper11_final = pd.concat([paper11_final, df], ignore_index=True)
paper11_final
# Out:
#               date   permno ticker      close       vol  day      mom1  \
# 0       2000-01-31  78927.0   SITC       13.0       NaN  0.0       NaN
# 1       2000-02-29  78927.0   SITC    11.5625  0.466334  1.0       NaN
# 2       2000-03-31  78927.0   SITC     13.875  0.097801  4.0 -0.110577
# 3       2000-04-28  78927.0   SITC    15.1875 -0.275115  4.0       0.2
# 4       2000-05-31  78927.0   SITC    14.4375 -0.193023  2.0  0.094595
# ...            ...      ...    ...        ...       ...  ...       ...
# 155988  2008-05-30  15472.0    WWY  77.129997  0.132117    4  0.211967
# 155989  2008-06-30  15472.0    WWY  77.779999 -0.273657    0  0.012736
# 155990  2008-07-31  15472.0    WWY  78.959999  0.061314    3  0.008427
# 155991  2008-08-29  15472.0    WWY  79.480003    -0.531    4  0.015171
# 155992  2008-09-30  15472.0    WWY  79.400002  1.456651    1  0.006586
#
#             mom2      mom3      roc5  ... TE3 TE5 TE6 DE1 DE2 DE4 DE5 DE6 Oil  \
# ...

# %%
len(paper9_final['ticker'].unique())
# Out:
# 833

# %%
paper11_final.to_csv('result/paper11_final/paper11_final.csv')

# %%
O = pd.read_csv('/Users/jinghuang/Desktop/MAS/high-priority-papers/result/paper9/O.csv', index_col=[0])
O = O.sort_values(by='date')
O.reset_index(inplace=True)
O = O.drop(columns = ['index'])
O
# Out:
#            date   permno ticker      close      spyt     spyt1     spyt2  \
# 0    2000-01-31  81045.0      O  21.250000 -0.658195  0.036685  0.036467
# 1    2000-02-29  81045.0      O  20.812500 -0.020588 -0.658195  0.036685
# 2    2000-03-31  81045.0      O  19.250000 -0.075075 -0.020588 -0.658195
# 3    2000-04-28  81045.0      O  21.812500  0.133117 -0.075075 -0.020588
# 4    2000-05-31  81045.0      O  23.625000  0.083095  0.133117 -0.075075
# ..          ...      ...    ...        ...       ...       ...       ...
# 247  2020-08-31  81045.0      O  62.029999  0.032973  0.009244  0.075755
# 248  2020-09-30  81045.0      O  60.750000 -0.020635  0.032973  0.009244
# 249  2020-10-30  81045.0      O  57.860001 -0.047572 -0.020635  0.032973
# 250  2020-11-30  81045.0      O  59.970001  0.036467 -0.047572 -0.020635
# 251  2020-12-31  81045.0      O  62.169998  0.036685  0.036467 -0.047572
#
#         spyt3       rdp5      rdp10  ...   de1   de2   de4   de5   de6   de7  \
# ...

# %%
paper6_final = pd.DataFrame()
count = 0
for filename in os.listdir('/Users/jinghuang/Desktop/MAS/high-priority-papers/result/paper6'):
    if '.csv' in filename:
        df = pd.read_csv('/Users/jinghuang/Desktop/MAS/high-priority-papers/result/paper6/'+filename, index_col=[0])
        if count == 0:
            paper6_final = df
            count += 1
        else:
            paper6_final = pd.concat([paper6_final, df], ignore_index=True)
paper6_final
# Out:
#               date   permno ticker      close  ma_1_9  ma_2_9  ma_3_9  \
# 0       2000-01-31  78927.0   SITC  13.000000       1       1       1
# 1       2000-02-29  78927.0   SITC  11.562500       0       0       0
# 2       2000-03-31  78927.0   SITC  13.875000       1       0       0
# 3       2000-04-28  78927.0   SITC  15.187500       1       1       0
# 4       2000-05-31  78927.0   SITC  14.437500       1       1       1
# ...            ...      ...    ...        ...     ...     ...     ...
# 155736  2008-05-30  15472.0    WWY  77.129997       1       1       1
# 155737  2008-06-30  15472.0    WWY  77.779999       1       1       1
# 155738  2008-07-31  15472.0    WWY  78.959999       1       1       1
# 155739  2008-08-29  15472.0    WWY  79.480003       1       1       1
# 155740  2008-09-30  15472.0    WWY  79.400002       1       1       1
#
#         ma_1_12  ma_2_12  ma_3_12  mom9  mom12  vol_1_9  vol_2_9  vol_3_9  \
# ...

# %%
paper6_final.to_csv('result/paper6_final/paper6_final.csv')

# %%
df = pd.read_csv('/Users/jinghuang/Desktop/MAS/high-priority-papers/result/consolidated_papers/BUD.csv', index_col=[0])
df
# Out:
#            date   permno ticker  ma_1_9  ma_2_9  ma_3_9  ma_1_12  ma_2_12  \
# 0    2000-01-31  59184.0    BUD       1       1       1        1        1
# 1    2000-02-29  59184.0    BUD       0       1       1        0        1
# 2    2000-03-31  59184.0    BUD       0       0       1        0        0
# 3    2000-04-28  59184.0    BUD       1       1       0        1        1
# 4    2000-05-31  59184.0    BUD       1       1       1        1        1
# ..          ...      ...    ...     ...     ...     ...      ...      ...
# 101  2008-06-30  59184.0    BUD       1       1       1        1        1
# 102  2008-07-31  59184.0    BUD       1       1       1        1        1
# 103  2008-08-29  59184.0    BUD       1       1       1        1        1
# 104  2008-09-30  59184.0    BUD       1       1       1        1        1
# 105  2008-10-31  59184.0    BUD       1       1       1        1        1
#
#      ma_3_12  mom9  ...     spyt2     spyt3       rdp5      rdp10      rdp15  \
# ...

# %%
df =df.sort_values(by='date')

# %%
df.reset_index(inplace=True)
df
# Out:
#      index        date   permno ticker  ma_1_9  ma_2_9  ma_3_9  ma_1_12  \
# 0        0  2000-01-31  59184.0    BUD       1       1       1        1
# 1        1  2000-02-29  59184.0    BUD       0       1       1        0
# 2        2  2000-03-31  59184.0    BUD       0       0       1        0
# 3        3  2000-04-28  59184.0    BUD       1       1       0        1
# 4        4  2000-05-31  59184.0    BUD       1       1       1        1
# ..     ...         ...      ...    ...     ...     ...     ...      ...
# 101    101  2008-06-30  59184.0    BUD       1       1       1        1
# 102    102  2008-07-31  59184.0    BUD       1       1       1        1
# 103    103  2008-08-29  59184.0    BUD       1       1       1        1
# 104    104  2008-09-30  59184.0    BUD       1       1       1        1
# 105    105  2008-10-31  59184.0    BUD       1       1       1        1
#
#      ma_2_12  ma_3_12  ...     spyt2     spyt3       rdp5      rdp10  \
# ...

# %%
con_final = pd.DataFrame()
count = 0
for filename in os.listdir('/Users/jinghuang/Desktop/MAS/high-priority-papers/result/consolidated_papers'):
    if '.csv' in filename:
        #print(filename)
        df = pd.read_csv('/Users/jinghuang/Desktop/MAS/high-priority-papers/result/consolidated_papers/'+filename, index_col=[0])
        df = df.sort_values(by='date')
        df.reset_index(inplace=True)
        if 'level_0' in df.columns: 
            df = df.drop(columns=['level_0'])
        if 'index' in df.columns: 
            df = df.drop(columns=['index'])
        
        if count == 0:
            con_final = df
            count += 1
        else:
            con_final = pd.concat([con_final, df], ignore_index=True)
        
con_final
# Out:
#               date   permno ticker  ma_1_9  ma_2_9  ma_3_9  ma_1_12  ma_2_12  \
# 0       2000-01-31  78927.0   SITC       1       1       1        1        1
# 1       2000-02-29  78927.0   SITC       0       1       1        0        1
# 2       2000-03-31  78927.0   SITC       1       0       1        1        0
# 3       2000-04-28  78927.0   SITC       1       1       1        1        1
# 4       2000-05-31  78927.0   SITC       1       1       1        1        1
# ...            ...      ...    ...     ...     ...     ...      ...      ...
# 190100  2008-05-30  15472.0    WWY       1       1       1        1        1
# 190101  2008-06-30  15472.0    WWY       1       1       1        1        1
# 190102  2008-07-31  15472.0    WWY       1       1       1        1        1
# 190103  2008-08-29  15472.0    WWY       1       1       1        1        1
# 190104  2008-09-30  15472.0    WWY       1       1       1        1        1
#
# ...

# %%
con_final.to_csv('consolidated_final.csv', index=False)

# %%
con_df = pd.read_csv('/Users/jinghuang/Desktop/MAS/high-priority-papers/consolidated_final.csv')
con_df
# Out:
#         Unnamed: 0        date   permno ticker  ma_1_9  ma_2_9  ma_3_9  \
# 0                0  2000-01-31  78927.0   SITC       1       1       1
# 1                1  2000-02-29  78927.0   SITC       0       1       1
# 2                2  2000-03-31  78927.0   SITC       1       0       1
# 3                3  2000-04-28  78927.0   SITC       1       1       1
# 4                4  2000-05-31  78927.0   SITC       1       1       1
# ...            ...         ...      ...    ...     ...     ...     ...
# 190100      190100  2008-05-30  15472.0    WWY       1       1       1
# 190101      190101  2008-06-30  15472.0    WWY       1       1       1
# 190102      190102  2008-07-31  15472.0    WWY       1       1       1
# 190103      190103  2008-08-29  15472.0    WWY       1       1       1
# 190104      190104  2008-09-30  15472.0    WWY       1       1       1
#
#         ma_1_12  ma_2_12  ma_3_12  ...  te6_y  de1_y  de2_y  de4_y  de5_y  \
# ...

# %%
con_df[con_df['ticker'] == 'O']
# Out:
#         Unnamed: 0        date   permno ticker  ma_1_9  ma_2_9  ma_3_9  \
# 169592      169592  2000-01-31  81045.0      O       0       0       0
# 169593      169593  2000-02-29  81045.0      O       0       0       0
# 169594      169594  2000-03-31  81045.0      O       0       0       0
# 169595      169595  2000-04-28  81045.0      O       0       0       0
# 169596      169596  2000-05-31  81045.0      O       0       0       0
# ...            ...         ...      ...    ...     ...     ...     ...
# 169839      169839  2020-08-31  81045.0      O       0       0       0
# 169840      169840  2020-09-30  81045.0      O       0       0       0
# 169841      169841  2020-10-30  81045.0      O       0       1       1
# 169842      169842  2020-11-30  81045.0      O       1       1       1
# 169843      169843  2020-12-31  81045.0      O       1       1       1
#
#         ma_1_12  ma_2_12  ma_3_12  ...  te6_y  de1_y  de2_y  de4_y  de5_y  \
# ...

# %%
p9 = pd.read_csv('/Users/jinghuang/Desktop/MAS/mas_empirical_assets_pricing_v5/data/paper9_final.csv')
p9
# Out:
#               date   permno ticker      close      spyt     spyt1     spyt2  \
# 0       2000-01-31  78927.0   SITC  13.000000       NaN       NaN       NaN
# 1       2000-02-29  78927.0   SITC  11.562500 -0.110577       NaN       NaN
# 2       2000-03-31  78927.0   SITC  13.875000  0.200000 -0.110577       NaN
# 3       2000-04-28  78927.0   SITC  15.187500  0.094595  0.200000 -0.110577
# 4       2000-05-31  78927.0   SITC  14.437500 -0.049383  0.094595  0.200000
# ...            ...      ...    ...        ...       ...       ...       ...
# 155736  2008-05-30  15472.0    WWY  77.129997  0.012736  0.211967  0.049783
# 155737  2008-06-30  15472.0    WWY  77.779999  0.008427  0.012736  0.211967
# 155738  2008-07-31  15472.0    WWY  78.959999  0.015171  0.008427  0.012736
# 155739  2008-08-29  15472.0    WWY  79.480003  0.006586  0.015171  0.008427
# 155740  2008-09-30  15472.0    WWY  79.400002 -0.001007  0.006586  0.015171
#
# ...

# %%
for col in p9.columns:
    print(col, type(p9[col][0]))
# Out:
# date <class 'str'>
# permno <class 'numpy.float64'>
# ticker <class 'str'>
# close <class 'numpy.float64'>
# spyt <class 'numpy.float64'>
# spyt1 <class 'numpy.float64'>
# spyt2 <class 'numpy.float64'>
# spyt3 <class 'numpy.float64'>
# rdp5 <class 'numpy.float64'>
# rdp10 <class 'numpy.float64'>
# rdp15 <class 'numpy.float64'>
# rdp20 <class 'numpy.float64'>
# ema10 <class 'numpy.float64'>
# ema20 <class 'numpy.float64'>
# ema50 <class 'numpy.float64'>
# ema200 <class 'numpy.float64'>
# fut_ret1 <class 'numpy.float64'>
# fut_ret2 <class 'numpy.float64'>
# close.1 <class 'numpy.float64'>
# spyt.1 <class 'numpy.float64'>
# spyt1.1 <class 'numpy.float64'>
# spyt2.1 <class 'numpy.float64'>
# spyt3.1 <class 'numpy.float64'>
# rdp5.1 <class 'numpy.float64'>
# rdp10.1 <class 'numpy.float64'>
# rdp15.1 <class 'numpy.float64'>
# rdp20.1 <class 'numpy.float64'>
# ema10.1 <class 'numpy.float64'>
# ema20.1 <class 'numpy.float64'>
# ema50.1 <class 'numpy.float64'>
# ...

# %%
cons = pd.read_csv('/Users/jinghuang/Desktop/MAS/mas_empirical_assets_pricing_v5/data/consolidated_final.csv')
cons
# Out:
#               date   permno ticker  ma_1_9  ma_2_9  ma_3_9  ma_1_12  ma_2_12  \
# 0       2000-01-31  78927.0   SITC       1       1       1        1        1
# 1       2000-02-29  78927.0   SITC       1       1       1        1        1
# 2       2000-03-31  78927.0   SITC       1       1       1        1        1
# 3       2000-04-28  78927.0   SITC       1       1       1        1        1
# 4       2000-05-31  78927.0   SITC       1       1       1        1        1
# ...            ...      ...    ...     ...     ...     ...      ...      ...
# 189983  2008-05-30  15472.0    WWY       1       1       1        1        1
# 189984  2008-06-30  15472.0    WWY       1       1       1        1        1
# 189985  2008-07-31  15472.0    WWY       1       1       1        1        1
# 189986  2008-08-29  15472.0    WWY       1       1       1        1        1
# 189987  2008-09-30  15472.0    WWY       1       1       1        1        1
#
# ...

# %%
for col in cons.columns:
    if isinstance(cons[col][0], str):
        print(col)
 #   print(col, type(cons[col][0]))
# Out:
# date
# ticker

# %%
import investpy

# %%
start_date = '30/12/1999'
end_date = '31/12/2020'

oil_brent = investpy.search.search_quotes(
        text='LCO', n_results=1).retrieve_historical_data(from_date=start_date, to_date=end_date)
oil_brent.rename(columns={'Change Pct': 'OIL_BRENT'}, inplace=True)

# %%
ixic_f = investpy.search.search_quotes(text='LCO', n_results=1)
print(ixic_f)
# Out:
# {"id_": 8833, "name": "Brent Oil Futures", "symbol": "LCO", "country": null, "tag": "/commodities/brent-oil", "pair_type": "commodities", "exchange": "ICE"}

# %%
search_result = investpy.search_quotes(text='ap', products=['stocks'],
                                       countries=['united states'], n_results=1)
print(search_result)
# Out:
# {"id_": 6408, "name": "Apple Inc", "symbol": "AAPL", "country": "united states", "tag": "/equities/apple-computer-inc", "pair_type": "stocks", "exchange": "NASDAQ"}

# %%
ixic_f = investpy.search.search_quotes(text='', n_results=1).retrieve_historical_data(
            from_date=start_date, to_date=end_date)
ixic_f.rename(columns={'Change Pct': 'IXIC_F'}, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 ixic_f = investpy.search.search_quotes(text='NQc1', n_results=1).retrieve_historical_data(
#       2             from_date=start_date, to_date=end_date)
#       3 ixic_f.rename(columns={'Change Pct': 'IXIC_F'}, inplace=True)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/investpy/search.py:167, in search_quotes(text, products, countries, n_results)
#     164 data = req.json()
#     166 if data["total"]["quotes"] == 0:
# --> 167     raise RuntimeError(
#     168         "ERR#0093: no results found on Investing.com for the introduced text."
#     169     )
#     171 if total_results is None:
#     172     total_results = data["total"]["quotes"]
#
# RuntimeError: ERR#0093: no results found on Investing.com for the introduced text.

# %%
import pandas as pd
pd.read_csv('/Users/jinghuang/Desktop/MAS/high-priority-papers/result/paper4/paper4_features.csv')
# Out:
#         Unnamed: 0        date  permno ticker          size         value  \
# 0                0  2000-01-31   10078   JAVA  1.314270e+03 -1.775891e-03
# 1                1  2000-02-29   10078   JAVA  1.226444e+08 -1.903063e-08
# 2                2  2000-03-31   10078   JAVA  1.486953e+08 -1.569652e-08
# 3                3  2000-04-28   10078   JAVA  1.486519e+08           NaN
# 4                4  2000-05-31   10078   JAVA  1.460543e+08           NaN
# ...            ...         ...     ...    ...           ...           ...
# 183216      183216  2020-08-31   93436   TSLA  2.666393e+08  2.482005e-05
# 183217      183217  2020-09-30   93436   TSLA  4.643391e+08  1.425252e-05
# 183218      183218  2020-10-30   93436   TSLA  4.067015e+08  1.627238e-05
# 183219      183219  2020-11-30   93436   TSLA  3.678235e+08  1.799232e-05
# 183220      183220  2020-12-31   93436   TSLA  5.380286e+08  1.230046e-05
#
#             prof   valprof     nissa    growth  ...     lrrev        valuem  \
# ...
